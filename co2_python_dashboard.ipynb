# %%
import pandas as pd
import numpy as np
import panel as pn
pn.extension("tabulator")
import hvplot.pandas
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
df = pd.read_csv("https://raw.githubusercontent.com/owid/co2-data/master/owid-co2-data.csv")

# %%
df
# Out:
#            country  year iso_code  population           gdp  cement_co2  \
# 0      Afghanistan  1850      AFG   3752993.0           NaN         NaN
# 1      Afghanistan  1851      AFG   3769828.0           NaN         NaN
# 2      Afghanistan  1852      AFG   3787706.0           NaN         NaN
# 3      Afghanistan  1853      AFG   3806634.0           NaN         NaN
# 4      Afghanistan  1854      AFG   3825655.0           NaN         NaN
# ...            ...   ...      ...         ...           ...         ...
# 46518     Zimbabwe  2017      ZWE  14751101.0  2.194784e+10       0.469
# 46519     Zimbabwe  2018      ZWE  15052191.0  2.271535e+10       0.558
# 46520     Zimbabwe  2019      ZWE  15354606.0           NaN       0.570
# 46521     Zimbabwe  2020      ZWE  15669663.0           NaN       0.570
# 46522     Zimbabwe  2021      ZWE  15993525.0           NaN       0.570
#
#        cement_co2_per_capita     co2  co2_growth_abs  co2_growth_prct  ...  \
# ...

# %%
df[df['country'] == 'North America']
# Out:
#              country  year iso_code   population  gdp  cement_co2  \
# 30258  North America  1750      NaN   11396206.0  NaN       0.000
# 30259  North America  1751      NaN          NaN  NaN       0.000
# 30260  North America  1752      NaN          NaN  NaN       0.000
# 30261  North America  1753      NaN          NaN  NaN       0.000
# 30262  North America  1754      NaN          NaN  NaN       0.000
# ...              ...   ...      ...          ...  ...         ...
# 30525  North America  2017      NaN  581258143.0  NaN      75.813
# 30526  North America  2018      NaN  585864285.0  NaN      74.562
# 30527  North America  2019      NaN  590497015.0  NaN      75.227
# 30528  North America  2020      NaN  594263186.0  NaN      75.718
# 30529  North America  2021      NaN  597123384.0  NaN      77.944
#
#        cement_co2_per_capita       co2  co2_growth_abs  co2_growth_prct  ...  \
# 30258                  0.000     0.000             NaN              NaN  ...
# ...

# %% [raw]
# # pre-process data

# %%
df = df.fillna(0)
df['gdp_per_capita'] = np.where(df['population'] != 0, df['gdp']/df['population'],0)

# %%
df[df['gdp'] != 0]
# Out:
#            country  year iso_code  population           gdp  cement_co2  \
# 100    Afghanistan  1950      AFG   7480464.0  9.421400e+09       0.000
# 101    Afghanistan  1951      AFG   7571542.0  9.692280e+09       0.000
# 102    Afghanistan  1952      AFG   7667534.0  1.001733e+10       0.000
# 103    Afghanistan  1953      AFG   7764549.0  1.063052e+10       0.000
# 104    Afghanistan  1954      AFG   7864289.0  1.086636e+10       0.000
# ...            ...   ...      ...         ...           ...         ...
# 46515     Zimbabwe  2014      ZWE  13855758.0  2.122250e+10       0.496
# 46516     Zimbabwe  2015      ZWE  14154937.0  2.102745e+10       0.585
# 46517     Zimbabwe  2016      ZWE  14452705.0  2.096179e+10       0.461
# 46518     Zimbabwe  2017      ZWE  14751101.0  2.194784e+10       0.469
# 46519     Zimbabwe  2018      ZWE  15052191.0  2.271535e+10       0.558
#
#        cement_co2_per_capita     co2  co2_growth_abs  co2_growth_prct  ...  \
# ...

# %%
idf = df.interactive()

# %% [raw]
# #co2 emission over time by continent

# %%
# Define Panel widgets
year_slider = pn.widgets.IntSlider(name='Year slider', start=1750, end=2020, step=5, value=1850)
year_slider
# Out:
# IntSlider(end=2020, name='Year slider', start=1750, step=5, value=1850)

# %%
# Radio buttons for CO2 measures
yaxis_co2 = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['co2', 'co2_per_capita',],
    button_type='success'
)

# %%
continents = ['World', 'Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica']

co2_pipeline = (
    idf[
        (idf.year <= year_slider) &
        (idf.country.isin(continents))
    ]
    .groupby(['country', 'year'])[yaxis_co2].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
co2_pipeline.head(5)
# Out:
# <div id='35827'>
#   <div class="bk-root" id="7617c1f9-16ee-4f55-9cb2-aa050a968168" data-root-id="35827"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
# ...

# %%
co2_plot = co2_pipeline.hvplot(x = 'year', by='country', y=yaxis_co2,line_width=2, title="CO2 emission by continent, year <= " + str(year_slider.value))
co2_plot
# Out:
# <div id='35837'>
#   <div class="bk-root" id="929c0187-a371-4233-966b-245cd291f795" data-root-id="35837"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
# ...

# %%
co2_table = co2_pipeline.pipe(pn.widgets.Tabulator, pagination='remote', page_size = 10, sizing_mode='stretch_width', show_index = False) 
co2_table
# Out:
# <div id='36324'>
#   <div class="bk-root" id="1dd89377-e5be-42d8-897e-5634178a032e" data-root-id="36324"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
# ...

# %% [raw]
# # CO2 vs GDP scatterplot

# %%
co2_vs_gdp_scatterplot_pipeline = (
    idf[
        (idf.year == year_slider) & (~(idf.country.isin(continents)))
    ]
    .groupby(['country', 'year', 'gdp_per_capita'])['co2'].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
co2_vs_gdp_scatterplot_pipeline.head(5)
# Out:
# <div id='36368'>
#   <div class="bk-root" id="4e46d846-a5b1-4cca-9552-02f0513a93bf" data-root-id="36368"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
# ...

# %%
co2_vs_gdp_scatterplot_table = co2_vs_gdp_scatterplot_pipeline.pipe(pn.widgets.Tabulator, pagination='remote', page_size = 10, sizing_mode='stretch_width', show_index = False) 
co2_vs_gdp_scatterplot_table
# Out:
# <div id='36377'>
#   <div class="bk-root" id="8e79ee02-fc61-417b-b433-0e749c1f6215" data-root-id="36377"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
# ...

# %%
co2_vs_gdp_scatterplot = co2_vs_gdp_scatterplot_pipeline.hvplot(x='gdp_per_capita', 
                                                                y='co2', 
                                                                by='country', 
                                                                size=80, kind="scatter", 
                                                                alpha=0.7,
                                                                legend=False, 
                                                                height=500, 
                                                                width=500,
                                                                title="CO2 vs GDP (year = " + str(year_slider.value)+")")
co2_vs_gdp_scatterplot
# Out:
# <div id='36425'>
#   <div class="bk-root" id="e2411fd4-bd0f-4a3d-870e-fc1fde6bc3f9" data-root-id="36425"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
# ...

# %% [raw]
# # Bar chart with CO2 sources by continent

# %%
yaxis_co2_source = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['coal_co2', 'oil_co2', 'gas_co2'], 
    button_type='success'
)

continents_excl_world = ['Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica']

co2_source_bar_pipeline = (
    idf[
        (idf.year == year_slider) &
        (idf.country.isin(continents_excl_world))
    ]
    .groupby(['year', 'country'])[yaxis_co2_source].sum()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
co2_source_bar_pipeline_table = co2_source_bar_pipeline.pipe(pn.widgets.Tabulator, pagination='remote', page_size = 10, sizing_mode='stretch_width', show_index = False)
co2_source_bar_pipeline_table
# Out:
# <div id='75519'>
#   <div class="bk-root" id="76352b2f-c6f0-4a27-ab41-b6c16f99aae4" data-root-id="75519"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
# ...

# %%
co2_source_bar_plot = co2_source_bar_pipeline.hvplot(kind='bar', 
                                                     x='continent', 
                                                     y=yaxis_co2_source, 
                                                     title='CO2 source by continent year = ' + str(year_slider.value) )
co2_source_bar_plot
# Out:
# <div id='62918'>
#   <div class="bk-root" id="bf090153-37e0-4d2c-a8ab-355fd9e43edf" data-root-id="62918"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
# ...

# %%
#Layout using Template
template = pn.template.FastListTemplate(
    title='World CO2 emission dashboard', 
    sidebar=[pn.pane.Markdown("# CO2 Emissions and Climate Change"), 
             pn.pane.PNG('climate_day.png', sizing_mode='scale_both'),
             pn.pane.Markdown("# Settings"),   
             year_slider],
    main=[pn.Row(pn.Column(yaxis_co2, 
                           co2_plot.panel(width=700), margin=(0,25)), 
                 co2_table.panel(width=500)), 
          pn.Row(pn.Column(co2_vs_gdp_scatterplot.panel(width=700), margin=(0,25)), 
                 co2_vs_gdp_scatterplot_table.panel(width=500)),
          pn.Row(pn.Column(yaxis_co2_source, co2_source_bar_plot.panel(width=700), margin=(0,25)),
                 co2_source_bar_pipeline_table.panel(width=500))
         ],
    accent_base_color="#88d8b0",
    header_background="#88d8b0",
)
template.show()
template.servable();
# Out:
# Launching server at http://localhost:64379
